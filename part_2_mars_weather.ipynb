# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import matplotlib.pyplot as plt
import pandas as pd

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://data-class-mars-challenge.s3.amazonaws.com/Mars/index.html). Inspect the page to identify which elements to scrape. Note that the URL is `https://data-class-mars-challenge.s3.amazonaws.com/Mars/index.html`.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
url = 'https://data-class-mars-challenge.s3.amazonaws.com/Mars/index.html'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
html_soup = soup(html, 'html.parser')
print(html_soup)
# Out:
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="Mark Otto, Jacob Thornton, and Bootstrap contributors" name="author"/>
# <meta content="Hugo 0.84.0" name="generator"/>
# <title>Mars Temperature Data</title>
# <link href="https://getbootstrap.com/docs/5.0/examples/jumbotron/" rel="canonical"/>
# <!-- Bootstrap core CSS -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
# <style>
#     .bd-placeholder-img {
#       font-size: 1.125rem;
#       text-anchor: middle;
#       -webkit-user-select: none;
#       -moz-user-select: none;
#       user-select: none;
#     }
#
#     @media (min-width: 768px) {
#       .bd-placeholder-img-lg {
#         font-size: 3.5rem;
#       }
#     }
#   </style>
# ...

# %%
# Extract all rows of data
datarow = html_soup.find_all('tr', class_='data-row')
# print(len(datarow))
# check the data in each row
# print(datarow)
for row in datarow:
    print("%s\n" % row)
# Out:
# <tr class="data-row">
# <td>2</td>
# <td>2012-08-16</td>
# <td>10</td>
# <td>155</td>
# <td>6</td>
# <td>-75.0</td>
# <td>739.0</td>
# </tr>
#
# <tr class="data-row">
# <td>13</td>
# <td>2012-08-17</td>
# <td>11</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>740.0</td>
# </tr>
#
# <tr class="data-row">
# <td>24</td>
# <td>2012-08-18</td>
# <td>12</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>741.0</td>
# </tr>
#
# <tr class="data-row">
# <td>35</td>
# <td>2012-08-19</td>
# <td>13</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>732.0</td>
# </tr>
#
# <tr class="data-row">
# <td>46</td>
# <td>2012-08-20</td>
# <td>14</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>740.0</td>
# </tr>
#
# <tr class="data-row">
# <td>57</td>
# <td>2012-08-21</td>
# <td>15</td>
# <td>158</td>
# <td>6</td>
# <td>-78.0</td>
# <td>740.0</td>
# </tr>
#
# <tr class="data-row">
# <td>68</td>
# <td>2012-08-22</td>
# <td>16</td>
# <td>158</td>
# <td>6</td>
# <td>-77.0</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
result=[]
Mara_Temperature = {}
# Loop through the scraped data to create a list of rows
for row in datarow:
    id = row.find_all('td')[0].text
    terrestrial_date = row.find_all('td')[1].text
    sol = row.find_all('td')[2].text
    ls = row.find_all('td')[3].text
    month = row.find_all('td')[4].text
    min_temp = row.find_all('td')[5].text
    pressure = row.find_all('td')[6].text
    #print("id:%s, t_date:%s, sol:%s, ls:%s, month:%s, min_temp:%s, pressure:%s" % (id, terrestrial_date, sol, ls, month, min_temp, pressure))
    result.append([id, terrestrial_date, sol, ls, month, min_temp, pressure])
print(result)
# Out:
# [['2', '2012-08-16', '10', '155', '6', '-75.0', '739.0'], ['13', '2012-08-17', '11', '156', '6', '-76.0', '740.0'], ['24', '2012-08-18', '12', '156', '6', '-76.0', '741.0'], ['35', '2012-08-19', '13', '157', '6', '-74.0', '732.0'], ['46', '2012-08-20', '14', '157', '6', '-74.0', '740.0'], ['57', '2012-08-21', '15', '158', '6', '-78.0', '740.0'], ['68', '2012-08-22', '16', '158', '6', '-77.0', '740.0'], ['79', '2012-08-23', '17', '159', '6', '-76.0', '742.0'], ['112', '2012-08-27', '21', '161', '6', '-74.0', '741.0'], ['114', '2012-08-28', '22', '162', '6', '-74.0', '742.0'], ['123', '2012-08-29', '23', '162', '6', '-75.0', '741.0'], ['134', '2012-08-30', '24', '163', '6', '-75.0', '742.0'], ['145', '2012-08-31', '25', '163', '6', '-75.0', '743.0'], ['156', '2012-09-01', '26', '164', '6', '-76.0', '745.0'], ['163', '2012-09-02', '27', '164', '6', '-75.0', '743.0'], ['170', '2012-09-03', '28', '165', '6', '-75.0', '745.0'], ['171', '2012-09-04', '29', '166', '6', '-75.0', '747.0'], ['1
# ...

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
#df = pd.DataFrame(data=all_rows,columns=headings)
#df = pd.read_html('https://data-class-mars-challenge.s3.amazonaws.com/Mars/index.html')
df = pd.DataFrame(columns=("id","terrestrial_date","sol","ls","month","min_temp","pressure"))
i = 0
for row in result:
    df.loc[i] = [row[0],row[1],row[2],row[3],row[4],row[5],row[6]]
    i+=1

# %%
# Confirm DataFrame was created successfully
df.head(10)
# Out:
#     id terrestrial_date sol   ls month min_temp pressure
# 0    2       2012-08-16  10  155     6    -75.0    739.0
# 1   13       2012-08-17  11  156     6    -76.0    740.0
# 2   24       2012-08-18  12  156     6    -76.0    741.0
# 3   35       2012-08-19  13  157     6    -74.0    732.0
# 4   46       2012-08-20  14  157     6    -74.0    740.0
# 5   57       2012-08-21  15  158     6    -78.0    740.0
# 6   68       2012-08-22  16  158     6    -77.0    740.0
# 7   79       2012-08-23  17  159     6    -76.0    742.0
# 8  112       2012-08-27  21  161     6    -74.0    741.0
# 9  114       2012-08-28  22  162     6    -74.0    742.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis

df["id"] = df["id"].astype(object).astype(int)
df['terrestrial_date'] = pd.to_datetime(df['terrestrial_date'])
df["sol"] = df["sol"].astype(object).astype(int)
df["ls"] = df["ls"].astype(object).astype(int)
df["month"] = df["month"].astype(object).astype(int)
df["min_temp"] = df["min_temp"].astype(object).astype(float)
df["pressure"] = df["pressure"].astype(object).astype(float)

# %%
# Confirm type changes were successful by examining data types again
df.dtypes
# Out:
# id                           int32
# terrestrial_date    datetime64[ns]
# sol                          int32
# ls                           int32
# month                        int32
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
months = df.month.unique()
print("There are %d months on Mars" % len(months))
# Out:
# There are 12 months on Mars

# %%
# 2. How many Martian days' worth of data are there?
num_sols = df.sol.unique()
#print(len(num_sols))
print("There are %d Martian days" % len(num_sols))
# Out:
# There are 1867 Martian days

# %%
# 3. What is the average low temperature by month?
df["min_temp"].mean()
# Out:
# -76.12104981253347

# %%
# List the average temperature by month
monthly_avg = df.groupby('month')['min_temp'].mean()
print(monthly_avg)
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average temperature by month
import numpy as np
import matplotlib.pyplot as plt
monthly_avg.plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Monthly_AVG Temperature")
plt.title("Average temperature by month")
# Out:
# Text(0.5, 1.0, 'Average temperature by month')

# %%
# Identify the coldest and hottest months in Curiosity's location
#min_number = min(monthly_avg)
#max_number = max(monthly_avg)
#print(min_number)
#print(max_number)

max_idx = monthly_avg.idxmax()
print("Hottest month at Curiosity's location:%s" % max_idx)
min_idx = monthly_avg.idxmin()
print("Coldest month at Curiosity's location:%s" % min_idx)
# Out:
# Hottest month at Curiosity's location:8
# Coldest month at Curiosity's location:3

# %%
# 4. Average pressure by Martian month
pressure_avg = df.groupby('month')['pressure'].mean()
print(pressure_avg)
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
pressure_avg.plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Average of Pressure")
plt.title("Average pressure by month")
# Out:
# Text(0.5, 1.0, 'Average pressure by month')

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
tdf = df.loc[df['ls'] == 155]
#print(tdf)
start_date = tdf.iloc[0,1]
#print(start_date)
end_date = tdf.iloc[1,1]
#print(end_date)


delta = end_date - start_date
print("There are %d terrestrial days in a Martian year." % delta.days)
# Out:
# There are 686 terrestrial days in a Martian year.

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
#filepath = path(r'"C:\Users\Violet.Huang\Documents\14_Berkerly bootscamp\Module 11\Challenge\Starter_Code\dataframe.csv")  
df.to_csv(r'C:\Users\Violet.Huang\Documents\14_Berkerly bootscamp\Module 11\Challenge\Starter_Code\dataframe.csv',index=False, header=True)
print(df)
# Out:
#         id terrestrial_date   sol   ls  month  min_temp  pressure
# 0        2       2012-08-16    10  155      6     -75.0     739.0
# 1       13       2012-08-17    11  156      6     -76.0     740.0
# 2       24       2012-08-18    12  156      6     -76.0     741.0
# 3       35       2012-08-19    13  157      6     -74.0     732.0
# 4       46       2012-08-20    14  157      6     -74.0     740.0
# ...    ...              ...   ...  ...    ...       ...       ...
# 1862  1889       2018-02-23  1973  133      5     -78.0     730.0
# 1863  1892       2018-02-24  1974  134      5     -77.0     729.0
# 1864  1894       2018-02-25  1975  134      5     -76.0     729.0
# 1865  1893       2018-02-26  1976  135      5     -77.0     728.0
# 1866  1895       2018-02-27  1977  135      5     -77.0     727.0
#
# [1867 rows x 7 columns]

# %%
browser.quit()
